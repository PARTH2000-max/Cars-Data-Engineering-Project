# %% [markdown]
# Create catalog

# %%
# %sql
create catalog cars_catalog;

# %% [markdown]
# create schemas

# %%
# %sql
CREATE SCHEMA cars_catalog.bronze
MANAGED LOCATION 'abfss://bronze@pmngradls.dfs.core.windows.net/';

CREATE SCHEMA cars_catalog.silver
MANAGED LOCATION 'abfss://silver@pmngradls.dfs.core.windows.net/';

CREATE SCHEMA cars_catalog.gold 
MANAGED LOCATION 'abfss://gold@pmngradls.dfs.core.windows.net/';
